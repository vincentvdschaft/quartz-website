# %% [markdown]
# # I/Q demodulation and envelope detection

# %%
import matplotlib.pyplot as plt
from scipy.signal import hilbert, butter, lfilter, bessel, filtfilt
import numpy as np
from pathlib import Path
from numpy.fft import fft, fftshift
import requests

# ======================================================================================
# Download the darkmode.mplstyle stylesheet and use it
# ======================================================================================
url = (r"https://raw.githubusercontent.com/vincentvdschaft/quartz-website/v4/figure-generation/darkmode.mplstyle")
r = requests.get(url)
with open('darkmode2.mplstyle', 'wb') as f:
    f.write(r.content)
plt.style.use('darkmode2.mplstyle')

def pulse(t, fc, tau):
    """Transmit pulse function. Returns a Gaussian pulse modulated by a sinusoid.

    Parameters
    ----------
    t : float, array-like
        The time vector.
    fc : float
        The frequency of the carrier signal.
    tau : float
        The time delay of the pulse.

    Returns
    -------
    array-like
        The transmit pulse.
    """
    sig = 1e-7
    return np.exp(-0.5 * ((t - tau) / sig) ** 2) * np.sin(2 * np.pi * fc * (t - tau))


def fft_sh(x):
    """Computes the magnitude of the FFT of a signal and shifts the zero frequency to
    the center.

    Parameters
    ----------
    x : array-like
        The input signal.

    Returns
    -------
    ndarray
        The magnitude of the FFT of the input signal.
    """
    return np.abs(fftshift(fft(x)))
# Out:
# Missing colon in file 'darkmode.mplstyle', line 7 ('<!DOCTYPE html>')
# Missing colon in file 'darkmode.mplstyle', line 8 ('<html')
# Missing colon in file 'darkmode.mplstyle', line 9 ('  lang="en"')
# Missing colon in file 'darkmode.mplstyle', line 11 ('  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"')
# Missing colon in file 'darkmode.mplstyle', line 12 ('  data-a11y-animated-images="system" data-a11y-link-underlines="true"')
# Missing colon in file 'darkmode.mplstyle', line 13 ('  >')
# Missing colon in file 'darkmode.mplstyle', line 18 ('  <head>')
# Missing colon in file 'darkmode.mplstyle', line 19 ('    <meta charset="utf-8">')
# Duplicate key in file 'darkmode.mplstyle', line 21 ('  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">')
# Duplicate key in file 'darkmode.mplstyle', line 22 ('  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">')
# Duplicate key in file 'darkmode.mplstyle', line 23 ('  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">')
# Duplicate key in file 'darkmode.mplstyle', line 25 ('  <link rel="preconnect" href="https://avatars.githubusercontent.com">')
# Duplicate key in file 'darkmode.mplstyle', line 31 ('    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-primitives-0b5bee5c70e9.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 32 ('    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-44fa1513ddd0.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 33 ('    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-1c8bb26336c1.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 34 ('    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-07f750db5d7c.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 35 ('  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/repository-fa69f138fe8d.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 36 ('<link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/code-111be5e4092d.css" />')
# Duplicate key in file 'darkmode.mplstyle', line 43 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_dompurify_dist_purify_js-6890e890956f.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 44 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_oddbird_popover-polyfill_dist_popover_js-7bd350d761f4.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 45 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_smoothscroll-polyfill_dist_smoothscroll_js-node_modules_stacktrace-parse-a448e4-bb5415637fe0.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 46 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/environment-775215f6b8df.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 47 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-9f960d9b217c.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 48 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_focus-zone_js-086f7a27bac0.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 49 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_relative-time-element_dist_index_js-c76945c5961a.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 50 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_combobox-nav_dist_index_js-node_modules_github_markdown-toolbar-e-820fc0-bc8f02b96749.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 51 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_auto-complete-element_dist_index_js-03fc21f4e80c.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 52 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_text-expander-element_dist_index_js-8a621df59e80.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 53 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_stacktrace-parser_dist_stack-443cd5-1ba4dbac454f.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 54 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_filter-input-element_dist_index_js-node_modules_github_remote-inp-b7d8f4-7dc906febe69.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 55 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_file-attachment-element_dist_index_js-node_modules_primer_view-co-27181b-3509ed8075c4.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 56 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_onfocus_ts-ui_packages_trusted-types-policies_policy_ts-ui_packages-6fe316-745e8b6794ab.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 57 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/github-elements-34cbf079a4f4.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 58 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/element-registry-cf592af12116.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 59 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_catalyst_lib_index_js-node_modules_github_hydro-analytics-client_-4da1df-9de8d527f925.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 60 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_braintree_browser-detection_dist_browser-detection_js-node_modules_githu-fd5530-6fc33e963fc0.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 61 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_lit-html_lit-html_js-5b376145beff.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 62 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_morphdom_dist_morphdom-esm_js-node_modules_github_memoize_dist_esm_index_js-05801f7ca718.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 63 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_turbo_dist_turbo_es2017-esm_js-c91f4ad18b62.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 64 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-893f9f-a8ec7ed862cf.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 65 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_scroll-anchoring_dist_scroll-anchoring_esm_js-node_modules_github_detail-c9d0ba-387cde917623.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 66 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_color-convert_index_js-72c9fbde5ad4.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 67 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_behaviors_dist_esm_dimensions_js-node_modules_github_jtml_lib_index_js-95b84ee6bc34.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 68 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_quote-selection_dist_index_js-node_modules_github_session-resume_-84957b-7b4e472db160.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 69 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_sudo_sudo_ts-eff4af278797.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 70 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_updatable-content_ts-ui_packages_hydro-analytics_hydro-analytics_ts-82813f-05346aa543fe.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 71 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_task-list_ts-app_assets_modules_github_onfocus_ts-app_ass-421cec-355eb4940fad.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 72 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_sticky-scroll-into-view_ts-94209c43e6af.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 73 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_ajax-error_ts-app_assets_modules_github_behaviors_include-467754-782c9388f902.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 74 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-9285faa0e011.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 75 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/behaviors-7f67a24be639.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 76 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_catalyst_lib_index_js-06ff531-2ea61fcc9a71.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 77 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/notifications-global-6d6db5144cc3.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 78 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_repositories_get-repo-element_ts-f6b365a47eda.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 79 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/code-menu-67595c3a6d0c.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 81 ('  <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/react-lib-1fbfc5be2c18.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 82 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_octicons-react_dist_index_esm_js-node_modules_primer_react_lib-es-541a38-6ce7d7c3f9ee.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 83 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Box_Box_js-8f8c5e2a2cbf.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 84 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Button_Button_js-95a7748e3c39.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 85 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_node_modules_primer_octicons-react_dist_index_esm_mjs-cb996b1b8e38.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 86 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_TooltipV2_Tooltip_js-a1d2cb4ed6ce.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 87 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_ActionList_index_js-e55780ce0aba.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 88 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Text_Text_js-node_modules_primer_react_lib-esm_Text-7845da-4af5adcf486a.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 89 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_FormControl_FormControl_js-2a0ace3735a5.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 90 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_AnchoredOverlay_AnchoredOverlay_js-61314bd0d65c.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 91 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_react-router-dom_dist_index_js-3b41341d50fe.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 92 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Heading_Heading_js-node_modules_primer_react_lib-es-09461f-46d4f0de9a1d.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 93 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_ConfirmationDialog_ConfirmationDialog_js-98120b3f8583.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 94 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Label_Label_js-node_modules_primer_react_lib-esm_Se-35d2ce-eb91f98e501d.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 95 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Dialog_js-node_modules_primer_react_lib-esm_TabNav_-8321f5-8bee569a21c5.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 96 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_AvatarStack_AvatarStack_js-node_modules_primer_reac-4256c8-7e2981ac3f9f.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 97 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_mini-throttle_dist_index_js-node_modules_primer_react_lib-esm_Bre-ed0fd7-8637a7921e06.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 98 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_react-core_create-browser-history_ts-ui_packages_safe-storage_safe-storage_ts-ui_-682c2c-e45e451173ec.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 99 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_react-core_register-app_ts-86733e888f0e.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 100 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_paths_index_ts-ad6a9a567cec.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 101 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_ref-selector_RefSelector_tsx-b257014a1aab.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 102 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_commit-attribution_index_ts-ui_packages_commit-checks-status_index_ts-ui_packages-bb2049-1abdf5af9393.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 103 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_react-shared_hooks_use-canonical-object_ts-ui_packages_code-view-shared_ho-e725dc-c2ba3df232d1.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 104 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/app_assets_modules_github_blob-anchor_ts-app_assets_modules_github_filter-sort_ts-app_assets_-e50ab6-fd8396d2490b.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 105 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/react-code-view-0204a0aa15e2.js"></script>')
# Missing colon in file 'darkmode.mplstyle', line 108 ('  <title>File not found · GitHub</title>')
# Missing colon in file 'darkmode.mplstyle', line 113 ('  <meta name="route-controller" content="blob" data-turbo-transient>')
# Missing colon in file 'darkmode.mplstyle', line 114 ('  <meta name="route-action" content="show" data-turbo-transient>')
# Missing colon in file 'darkmode.mplstyle', line 117 ('  <meta name="current-catalog-service-hash" content="82c569b93da5c18ed649ebd4c2c79437db4611a6a1373e805a3cb001c64130b7">')
# Missing colon in file 'darkmode.mplstyle', line 126 ('  <meta name="github-keyboard-shortcuts" content="repository,source-code,file-tree,copilot" data-turbo-transient="true" />')
# Missing colon in file 'darkmode.mplstyle', line 129 ('  <meta name="selected-link" value="repo_source" data-turbo-transient>')
# Missing colon in file 'darkmode.mplstyle', line 132 ('    <meta name="google-site-verification" content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY">')
# Missing colon in file 'darkmode.mplstyle', line 133 ('  <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">')
# Missing colon in file 'darkmode.mplstyle', line 134 ('  <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">')
# Missing colon in file 'darkmode.mplstyle', line 135 ('  <meta name="google-site-verification" content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">')
# Missing colon in file 'darkmode.mplstyle', line 136 ('  <meta name="google-site-verification" content="Apib7-x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I">')
# Missing colon in file 'darkmode.mplstyle', line 140 ('  <meta name="analytics-location" content="/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show" data-turbo-transient="true" />')
# Missing colon in file 'darkmode.mplstyle', line 148 ('    <meta name="user-login" content="">')
# Missing colon in file 'darkmode.mplstyle', line 152 ('    <meta name="viewport" content="width=device-width">')
# Missing colon in file 'darkmode.mplstyle', line 156 ('      <meta name="description" content="Contribute to vincentvdschaft/quartz-website development by creating an account on GitHub.">')
# Missing colon in file 'darkmode.mplstyle', line 158 ('      <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">')
# Missing colon in file 'darkmode.mplstyle', line 171 ('      <meta name="hostname" content="github.com">')
# Missing colon in file 'darkmode.mplstyle', line 175 ('        <meta name="expected-hostname" content="github.com">')
# Missing colon in file 'darkmode.mplstyle', line 178 ('  <meta http-equiv="x-pjax-version" content="15f148cc84602d9ce96b6a1d55145118bd93549b85fb71f8ec8450327cc5a1a6" data-turbo-track="reload">')
# Missing colon in file 'darkmode.mplstyle', line 179 ('  <meta http-equiv="x-pjax-csp-version" content="f226bf37af9c33162063db3eb018fed7f088f86d0a20ca54c013fda96c7f2e05" data-turbo-track="reload">')
# Missing colon in file 'darkmode.mplstyle', line 180 ('  <meta http-equiv="x-pjax-css-version" content="c7c53f4a8c1805ddf3ad2b644dd42a4962efe1cdc844e0f7d13ea6efe106ef15" data-turbo-track="reload">')
# Missing colon in file 'darkmode.mplstyle', line 181 ('  <meta http-equiv="x-pjax-js-version" content="6fb3d26ce53f202b5aba221170223ea3a727694ad51b62cbaad70ba887801bd0" data-turbo-track="reload">')
# Missing colon in file 'darkmode.mplstyle', line 183 ('  <meta name="turbo-cache-control" content="no-preview" data-turbo-transient="">')
# Missing colon in file 'darkmode.mplstyle', line 185 ('      <meta name="turbo-cache-control" content="no-cache" data-turbo-transient>')
# Missing colon in file 'darkmode.mplstyle', line 186 ('    <meta data-hydrostats="publish">')
# Duplicate key in file 'darkmode.mplstyle', line 187 ('  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/react-code-view.959fb0b61e6a1de773e7.module.css" />')
# Missing colon in file 'darkmode.mplstyle', line 190 ('  <meta name="octolytics-dimension-user_id" content="51445631" /><meta name="octolytics-dimension-user_login" content="vincentvdschaft" /><meta name="octolytics-dimension-repository_id" content="782880150" /><meta name="octolytics-dimension-repository_nwo" content="vincentvdschaft/quartz-website" /><meta name="octolytics-dimension-repository_public" content="true" /><meta name="octolytics-dimension-repository_is_fork" content="false" /><meta name="octolytics-dimension-repository_network_root_id" content="782880150" /><meta name="octolytics-dimension-repository_network_root_nwo" content="vincentvdschaft/quartz-website" />')
# Missing colon in file 'darkmode.mplstyle', line 196 ('    <meta name="turbo-body-classes" content="logged-out env-production page-responsive">')
# Missing colon in file 'darkmode.mplstyle', line 207 ('<meta name="theme-color" content="#1e2327">')
# Missing colon in file 'darkmode.mplstyle', line 208 ('<meta name="color-scheme" content="light dark" />')
# Missing colon in file 'darkmode.mplstyle', line 211 ('  <link rel="manifest" href="/manifest.json" crossOrigin="use-credentials">')
# Missing colon in file 'darkmode.mplstyle', line 213 ('  </head>')
# Missing colon in file 'darkmode.mplstyle', line 220 ('    <div class="position-relative js-header-wrapper ">')
# Missing colon in file 'darkmode.mplstyle', line 221 ('      <a href="#start-of-content" class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content">Skip to content</a>')
# Missing colon in file 'darkmode.mplstyle', line 222 ('      <span data-view-component="true" class="progress-pjax-loader Progress position-fixed width-full">')
# Missing colon in file 'darkmode.mplstyle', line 224 ('</span>      ')
# Duplicate key in file 'darkmode.mplstyle', line 235 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_primer_react_lib-esm_Button_IconButton_js-node_modules_primer_react_lib--b964b4-6ad237e6932f.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 237 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/keyboard-shortcuts-dialog-b4a646a773af.js"></script>')
# Missing colon in file 'darkmode.mplstyle', line 239 ('<react-partial')
# Missing colon in file 'darkmode.mplstyle', line 240 ('  partial-name="keyboard-shortcuts-dialog"')
# Missing colon in file 'darkmode.mplstyle', line 241 ('  data-ssr="false"')
# Missing colon in file 'darkmode.mplstyle', line 242 ('>')
# Missing colon in file 'darkmode.mplstyle', line 245 ('  <div data-target="react-partial.reactRoot"></div>')
# Missing colon in file 'darkmode.mplstyle', line 246 ('</react-partial>')
# Duplicate key in file 'darkmode.mplstyle', line 256 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_remote-form_dist_index_js-node_modules_delegated-events_dist_inde-94fd67-9f3636b94e7e.js"></script>')
# Duplicate key in file 'darkmode.mplstyle', line 257 ('<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/sessions-ff11af600d3e.js"></script>')
# Missing colon in file 'darkmode.mplstyle', line 258 ('<header class="Header-old header-logged-out js-details-container Details position-relative f4 py-3" role="banner" data-color-mode=light data-light-theme=light data-dark-theme=dark>')
# Missing colon in file 'darkmode.mplstyle', line 259 ('  <button type="button" class="Header-backdrop d-lg-none border-0 position-fixed top-0 left-0 width-full height-full js-details-target" aria-label="Toggle navigation">')
# Missing colon in file 'darkmode.mplstyle', line 260 ('    <span class="d-none">Toggle navigation</span>')
# Missing colon in file 'darkmode.mplstyle', line 261 ('  </button>')
# Missing colon in file 'darkmode.mplstyle', line 263 ('  <div class=" d-flex flex-column flex-lg-row flex-items-center p-responsive height-full position-relative z-1">')
# Missing colon in file 'darkmode.mplstyle', line 264 ('    <div class="d-flex flex-justify-between flex-items-center width-full width-lg-auto">')
# Missing colon in file 'darkmode.mplstyle', line 266 ('        <svg height="32" aria-hidden="true" viewBox="0 0 16 16" version="1.1" width="32" data-view-component="true" class="octicon octicon-mark-github">')
# Missing colon in file 'darkmode.mplstyle', line 267 ('    <path d="M8 0c4.42 0 8 3.58 8 8a8.013 8.013 0 0 1-5.45 7.59c-.4.08-.55-.17-.55-.38 0-.27.01-1.13.01-2.2 0-.75-.25-1.23-.54-1.48 1.78-.2 3.65-.88 3.65-3.95 0-.88-.31-1.59-.82-2.15.08-.2.36-1.02-.08-2.12 0 0-.67-.22-2.2.82-.64-.18-1.32-.27-2-.27-.68 0-1.36.09-2 .27-1.53-1.03-2.2-.82-2.2-.82-.44 1.1-.16 1.92-.08 2.12-.51.56-.82 1.28-.82 2.15 0 3.06 1.86 3.75 3.64 3.95-.23.2-.44.55-.51 1.07-.46.21-1.61.55-2.33-.66-.15-.24-.6-.83-1.23-.82-.67.01-.27.38.01.53.34.19.73.9.82 1.13.16.45.68 1.31 2.69.94 0 .67.01 1.3.01 1.49 0 .21-.15.45-.55.38A7.995 7.995 0 0 1 0 8c0-4.42 3.58-8 8-8Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 268 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 269 ('      </a>')
# Missing colon in file 'darkmode.mplstyle', line 271 ('      <div class="flex-1">')
# Missing colon in file 'darkmode.mplstyle', line 272 ('        <a href="/login?return_to=https%3A%2F%2Fgithub.com%2Fvincentvdschaft%2Fquartz-website%2Fblob%2Fv4%2Ffigure-generation%2Fdarkmode.mplstyle%3Fraw%3Dtrue"')
# Missing colon in file 'darkmode.mplstyle', line 273 ('          class="d-inline-block d-lg-none flex-order-1 f5 no-underline border color-border-default rounded-2 px-2 py-1 color-fg-inherit"')
# Missing colon in file 'darkmode.mplstyle', line 276 ('          Sign in')
# Missing colon in file 'darkmode.mplstyle', line 277 ('        </a>')
# Missing colon in file 'darkmode.mplstyle', line 278 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 280 ('      <div class="flex-1 flex-order-2 text-right">')
# Missing colon in file 'darkmode.mplstyle', line 281 ('        <button aria-label="Toggle navigation" aria-expanded="false" type="button" data-view-component="true" class="js-details-target Button--link Button--medium Button d-lg-none color-fg-inherit p-1">  <span class="Button-content">')
# Missing colon in file 'darkmode.mplstyle', line 282 ('    <span class="Button-label"><div class="HeaderMenu-toggle-bar rounded my-1"></div>')
# Missing colon in file 'darkmode.mplstyle', line 283 ('            <div class="HeaderMenu-toggle-bar rounded my-1"></div>')
# Missing colon in file 'darkmode.mplstyle', line 284 ('            <div class="HeaderMenu-toggle-bar rounded my-1"></div></span>')
# Missing colon in file 'darkmode.mplstyle', line 285 ('  </span>')
# Missing colon in file 'darkmode.mplstyle', line 286 ('</button>')
# Missing colon in file 'darkmode.mplstyle', line 287 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 288 ('    </div>')
# Missing colon in file 'darkmode.mplstyle', line 291 ('    <div class="HeaderMenu--logged-out p-responsive height-fit position-lg-relative d-lg-flex flex-column flex-auto pt-7 pb-4 top-0">')
# Missing colon in file 'darkmode.mplstyle', line 292 ('      <div class="header-menu-wrapper d-flex flex-column flex-self-end flex-lg-row flex-justify-between flex-auto p-3 p-lg-0 rounded rounded-lg-0 mt-3 mt-lg-0">')
# Missing colon in file 'darkmode.mplstyle', line 293 ('          <nav class="mt-0 px-3 px-lg-0 mb-3 mb-lg-0" aria-label="Global">')
# Missing colon in file 'darkmode.mplstyle', line 294 ('            <ul class="d-lg-flex list-style-none">')
# Missing colon in file 'darkmode.mplstyle', line 295 ('                <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">')
# Missing colon in file 'darkmode.mplstyle', line 296 ('      <button type="button" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-3 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" aria-expanded="false">')
# Missing colon in file 'darkmode.mplstyle', line 297 ('        Product')
# Missing colon in file 'darkmode.mplstyle', line 298 ('        <svg opacity="0.5" aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1">')
# Missing colon in file 'darkmode.mplstyle', line 299 ('    <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 300 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 301 ('      </button>')
# Missing colon in file 'darkmode.mplstyle', line 302 ('      <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 py-2 py-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 d-lg-flex dropdown-menu-wide">')
# Missing colon in file 'darkmode.mplstyle', line 303 ('          <div class="px-lg-4 border-lg-right mb-4 mb-lg-0 pr-lg-7">')
# Missing colon in file 'darkmode.mplstyle', line 304 ('            <ul class="list-style-none f5" >')
# Missing colon in file 'darkmode.mplstyle', line 305 ('                <li>')
# Missing colon in file 'darkmode.mplstyle', line 307 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-workflow color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 308 ('    <path d="M1 3a2 2 0 0 1 2-2h6.5a2 2 0 0 1 2 2v6.5a2 2 0 0 1-2 2H7v4.063C7 16.355 7.644 17 8.438 17H12.5v-2.5a2 2 0 0 1 2-2H21a2 2 0 0 1 2 2V21a2 2 0 0 1-2 2h-6.5a2 2 0 0 1-2-2v-2.5H8.437A2.939 2.939 0 0 1 5.5 15.562V11.5H3a2 2 0 0 1-2-2Zm2-.5a.5.5 0 0 0-.5.5v6.5a.5.5 0 0 0 .5.5h6.5a.5.5 0 0 0 .5-.5V3a.5.5 0 0 0-.5-.5ZM14.5 14a.5.5 0 0 0-.5.5V21a.5.5 0 0 0 .5.5H21a.5.5 0 0 0 .5-.5v-6.5a.5.5 0 0 0-.5-.5Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 309 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 310 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 311 ('        <div class="color-fg-default h4">Actions</div>')
# Missing colon in file 'darkmode.mplstyle', line 312 ('        Automate any workflow')
# Missing colon in file 'darkmode.mplstyle', line 313 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 316 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 318 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 319 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Packages&quot;,&quot;label&quot;:&quot;ref_cta:Packages;&quot;}" href="/features/packages">')
# Missing colon in file 'darkmode.mplstyle', line 320 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-package color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 321 ('    <path d="M12.876.64V.639l8.25 4.763c.541.313.875.89.875 1.515v9.525a1.75 1.75 0 0 1-.875 1.516l-8.25 4.762a1.748 1.748 0 0 1-1.75 0l-8.25-4.763a1.75 1.75 0 0 1-.875-1.515V6.917c0-.625.334-1.202.875-1.515L11.126.64a1.748 1.748 0 0 1 1.75 0Zm-1 1.298L4.251 6.34l7.75 4.474 7.75-4.474-7.625-4.402a.248.248 0 0 0-.25 0Zm.875 19.123 7.625-4.402a.25.25 0 0 0 .125-.216V7.639l-7.75 4.474ZM3.501 7.64v8.803c0 .09.048.172.125.216l7.625 4.402v-8.947Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 322 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 323 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 324 ('        <div class="color-fg-default h4">Packages</div>')
# Missing colon in file 'darkmode.mplstyle', line 325 ('        Host and manage packages')
# Missing colon in file 'darkmode.mplstyle', line 326 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 329 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 331 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 332 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Security&quot;,&quot;label&quot;:&quot;ref_cta:Security;&quot;}" href="/features/security">')
# Missing colon in file 'darkmode.mplstyle', line 333 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-shield-check color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 334 ('    <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97-1.97a.75.75 0 0 0-1.06 1.06l2.5 2.5a.75.75 0 0 0 1.06 0l5-5Z"></path><path d="m12.54.637 8.25 2.675A1.75 1.75 0 0 1 22 4.976V10c0 6.19-3.771 10.704-9.401 12.83a1.704 1.704 0 0 1-1.198 0C5.77 20.705 2 16.19 2 10V4.976c0-.758.489-1.43 1.21-1.664L11.46.637a1.748 1.748 0 0 1 1.08 0Zm-.617 1.426-8.25 2.676a.249.249 0 0 0-.173.237V10c0 5.46 3.28 9.483 8.43 11.426a.199.199 0 0 0 .14 0C17.22 19.483 20.5 15.461 20.5 10V4.976a.25.25 0 0 0-.173-.237l-8.25-2.676a.253.253 0 0 0-.154 0Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 335 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 336 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 337 ('        <div class="color-fg-default h4">Security</div>')
# Missing colon in file 'darkmode.mplstyle', line 338 ('        Find and fix vulnerabilities')
# Missing colon in file 'darkmode.mplstyle', line 339 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 342 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 344 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 345 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Codespaces&quot;,&quot;label&quot;:&quot;ref_cta:Codespaces;&quot;}" href="/features/codespaces">')
# Missing colon in file 'darkmode.mplstyle', line 346 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-codespaces color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 347 ('    <path d="M3.5 3.75C3.5 2.784 4.284 2 5.25 2h13.5c.966 0 1.75.784 1.75 1.75v7.5A1.75 1.75 0 0 1 18.75 13H5.25a1.75 1.75 0 0 1-1.75-1.75Zm-2 12c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v4a1.75 1.75 0 0 1-1.75 1.75H3.25a1.75 1.75 0 0 1-1.75-1.75ZM5.25 3.5a.25.25 0 0 0-.25.25v7.5c0 .138.112.25.25.25h13.5a.25.25 0 0 0 .25-.25v-7.5a.25.25 0 0 0-.25-.25Zm-2 12a.25.25 0 0 0-.25.25v4c0 .138.112.25.25.25h17.5a.25.25 0 0 0 .25-.25v-4a.25.25 0 0 0-.25-.25Z"></path><path d="M10 17.75a.75.75 0 0 1 .75-.75h6.5a.75.75 0 0 1 0 1.5h-6.5a.75.75 0 0 1-.75-.75Zm-4 0a.75.75 0 0 1 .75-.75h.5a.75.75 0 0 1 0 1.5h-.5a.75.75 0 0 1-.75-.75Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 348 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 349 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 350 ('        <div class="color-fg-default h4">Codespaces</div>')
# Missing colon in file 'darkmode.mplstyle', line 351 ('        Instant dev environments')
# Missing colon in file 'darkmode.mplstyle', line 352 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 355 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 357 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 358 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Copilot&quot;,&quot;label&quot;:&quot;ref_cta:Copilot;&quot;}" href="/features/copilot">')
# Missing colon in file 'darkmode.mplstyle', line 359 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-copilot color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 360 ('    <path d="M23.922 16.992c-.861 1.495-5.859 5.023-11.922 5.023-6.063 0-11.061-3.528-11.922-5.023A.641.641 0 0 1 0 16.736v-2.869a.841.841 0 0 1 .053-.22c.372-.935 1.347-2.292 2.605-2.656.167-.429.414-1.055.644-1.517a10.195 10.195 0 0 1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952 1.399-1.136 3.392-2.093 6.122-2.093 2.731 0 4.767.957 6.166 2.093.584.235 1.077.546 1.474.952.85.869 1.132 2.037 1.132 3.368 0 .368-.014.733-.052 1.086.23.462.477 1.088.644 1.517 1.258.364 2.233 1.721 2.605 2.656a.832.832 0 0 1 .053.22v2.869a.641.641 0 0 1-.078.256ZM12.172 11h-.344a4.323 4.323 0 0 1-.355.508C10.703 12.455 9.555 13 7.965 13c-1.725 0-2.989-.359-3.782-1.259a2.005 2.005 0 0 1-.085-.104L4 11.741v6.585c1.435.779 4.514 2.179 8 2.179 3.486 0 6.565-1.4 8-2.179v-6.585l-.098-.104s-.033.045-.085.104c-.793.9-2.057 1.259-3.782 1.259-1.59 0-2.738-.545-3.508-1.492a4.323 4.323 0 0 1-.355-.508h-.016.016Zm.641-2.935c.136 1.057.403 1.913.878 2.497.442.544 1.134.938 2.344.938 1.573 0 2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626 0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169-1.271-.438-1.578-.341-.391-1.046-.69-2.533-.529-1.505.163-2.347.537-2.824 1.025-.462.472-.705 1.179-.705 2.319 0 1.211.175 1.926.558 2.361.365.414 1.084.751 2.657.751 1.21 0 1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z"></path><path d="M14.5 14.25a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Zm-5 0a1 1 0 0 1 1 1v2a1 1 0 0 1-2 0v-2a1 1 0 0 1 1-1Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 361 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 362 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 363 ('        <div class="color-fg-default h4">Copilot</div>')
# Missing colon in file 'darkmode.mplstyle', line 364 ('        Write better code with AI')
# Missing colon in file 'darkmode.mplstyle', line 365 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 368 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 370 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 371 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Code review&quot;,&quot;label&quot;:&quot;ref_cta:Code review;&quot;}" href="/features/code-review">')
# Missing colon in file 'darkmode.mplstyle', line 372 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-code-review color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 373 ('    <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908 2.7 2.908 2.7a.75.75 0 1 1-1.02 1.1l-3.5-3.25a.75.75 0 0 1 0-1.1l3.5-3.25a.75.75 0 0 1 1.06.04Zm3.44 1.06a.75.75 0 1 1 1.02-1.1l3.5 3.25a.75.75 0 0 1 0 1.1l-3.5 3.25a.75.75 0 1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M1.5 4.25c0-.966.784-1.75 1.75-1.75h17.5c.966 0 1.75.784 1.75 1.75v12.5a1.75 1.75 0 0 1-1.75 1.75h-9.69l-3.573 3.573A1.458 1.458 0 0 1 5 21.043V18.5H3.25a1.75 1.75 0 0 1-1.75-1.75ZM3.25 4a.25.25 0 0 0-.25.25v12.5c0 .138.112.25.25.25h2.5a.75.75 0 0 1 .75.75v3.19l3.72-3.72a.749.749 0 0 1 .53-.22h10a.25.25 0 0 0 .25-.25V4.25a.25.25 0 0 0-.25-.25Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 374 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 375 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 376 ('        <div class="color-fg-default h4">Code review</div>')
# Missing colon in file 'darkmode.mplstyle', line 377 ('        Manage code changes')
# Missing colon in file 'darkmode.mplstyle', line 378 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 381 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 383 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 384 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center pb-lg-3" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Product&quot;,&quot;action&quot;:&quot;click to go to Issues&quot;,&quot;label&quot;:&quot;ref_cta:Issues;&quot;}" href="/features/issues">')
# Missing colon in file 'darkmode.mplstyle', line 385 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-issue-opened color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 386 ('    <path d="M12 1c6.075 0 11 4.925 11 11s-4.925 11-11 11S1 18.075 1 12 5.925 1 12 1ZM2.5 12a9.5 9.5 0 0 0 9.5 9.5 9.5 9.5 0 0 0 9.5-9.5A9.5 9.5 0 0 0 12 2.5 9.5 9.5 0 0 0 2.5 12Zm9.5 2a2 2 0 1 1-.001-3.999A2 2 0 0 1 12 14Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 387 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 388 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 389 ('        <div class="color-fg-default h4">Issues</div>')
# Missing colon in file 'darkmode.mplstyle', line 390 ('        Plan and track work')
# Missing colon in file 'darkmode.mplstyle', line 391 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 394 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 396 ('                <li>')
# Missing colon in file 'darkmode.mplstyle', line 398 ('      <svg aria-hidden="true" height="24" viewBox="0 0 24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3">')
# Missing colon in file 'darkmode.mplstyle', line 399 ('    <path d="M1.75 1h12.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 14.25 14H8.061l-2.574 2.573A1.458 1.458 0 0 1 3 15.543V14H1.75A1.75 1.75 0 0 1 0 12.25v-9.5C0 1.784.784 1 1.75 1ZM1.5 2.75v9.5c0 .138.112.25.25.25h2a.75.75 0 0 1 .75.75v2.19l2.72-2.72a.749.749 0 0 1 .53-.22h6.5a.25.25 0 0 0 .25-.25v-9.5a.25.25 0 0 0-.25-.25H1.75a.25.25 0 0 0-.25.25Z"></path><path d="M22.5 8.75a.25.25 0 0 0-.25-.25h-3.5a.75.75 0 0 1 0-1.5h3.5c.966 0 1.75.784 1.75 1.75v9.5A1.75 1.75 0 0 1 22.25 20H21v1.543a1.457 1.457 0 0 1-2.487 1.03L15.939 20H10.75A1.75 1.75 0 0 1 9 18.25v-1.465a.75.75 0 0 1 1.5 0v1.465c0 .138.112.25.25.25h5.5a.75.75 0 0 1 .53.22l2.72 2.72v-2.19a.75.75 0 0 1 .75-.75h2a.25.25 0 0 0 .25-.25v-9.5Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 400 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 401 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 402 ('        <div class="color-fg-default h4">Discussions</div>')
# Missing colon in file 'darkmode.mplstyle', line 403 ('        Collaborate outside of code')
# Missing colon in file 'darkmode.mplstyle', line 404 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 407 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 409 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 410 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 411 ('          <div class="px-lg-4">')
# Missing colon in file 'darkmode.mplstyle', line 412 ('              <span class="d-block h4 color-fg-default my-1" id="product-explore-heading">Explore</span>')
# Missing colon in file 'darkmode.mplstyle', line 413 ('            <ul class="list-style-none f5" aria-labelledby="product-explore-heading">')
# Missing colon in file 'darkmode.mplstyle', line 414 ('                <li>')
# Missing colon in file 'darkmode.mplstyle', line 416 ('      All features')
# Missing colon in file 'darkmode.mplstyle', line 419 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 421 ('                <li>')
# Missing colon in file 'darkmode.mplstyle', line 423 ('      Documentation')
# ...
# Missing colon in file 'darkmode.mplstyle', line 539 ('      White papers, Ebooks, Webinars')
# Missing colon in file 'darkmode.mplstyle', line 541 ('    <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">')
# Missing colon in file 'darkmode.mplstyle', line 542 ('    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 543 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 544 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 546 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 547 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Solutions&quot;,&quot;action&quot;:&quot;click to go to Customer Stories&quot;,&quot;label&quot;:&quot;ref_cta:Customer Stories;&quot;}" href="/customer-stories">')
# Missing colon in file 'darkmode.mplstyle', line 548 ('      Customer Stories')
# Missing colon in file 'darkmode.mplstyle', line 551 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 553 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 554 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Solutions&quot;,&quot;action&quot;:&quot;click to go to Partners&quot;,&quot;label&quot;:&quot;ref_cta:Partners;&quot;}" href="https://partner.github.com">')
# Missing colon in file 'darkmode.mplstyle', line 555 ('      Partners')
# Missing colon in file 'darkmode.mplstyle', line 557 ('    <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">')
# Missing colon in file 'darkmode.mplstyle', line 558 ('    <path d="M3.75 2h3.5a.75.75 0 0 1 0 1.5h-3.5a.25.25 0 0 0-.25.25v8.5c0 .138.112.25.25.25h8.5a.25.25 0 0 0 .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75 1.75 0 0 1 12.25 14h-8.5A1.75 1.75 0 0 1 2 12.25v-8.5C2 2.784 2.784 2 3.75 2Zm6.854-1h4.146a.25.25 0 0 1 .25.25v4.146a.25.25 0 0 1-.427.177L13.03 4.03 9.28 7.78a.751.751 0 0 1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 559 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 560 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 562 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 563 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 564 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 565 ('</li>')
# Missing colon in file 'darkmode.mplstyle', line 568 ('                <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">')
# Missing colon in file 'darkmode.mplstyle', line 569 ('      <button type="button" class="HeaderMenu-link border-0 width-full width-lg-auto px-0 px-lg-2 py-3 py-lg-2 no-wrap d-flex flex-items-center flex-justify-between js-details-target" aria-expanded="false">')
# Missing colon in file 'darkmode.mplstyle', line 570 ('        Open Source')
# Missing colon in file 'darkmode.mplstyle', line 571 ('        <svg opacity="0.5" aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1">')
# Missing colon in file 'darkmode.mplstyle', line 572 ('    <path d="M12.78 5.22a.749.749 0 0 1 0 1.06l-4.25 4.25a.749.749 0 0 1-1.06 0L3.22 6.28a.749.749 0 1 1 1.06-1.06L8 8.939l3.72-3.719a.749.749 0 0 1 1.06 0Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 573 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 574 ('      </button>')
# Missing colon in file 'darkmode.mplstyle', line 575 ('      <div class="HeaderMenu-dropdown dropdown-menu rounded m-0 p-0 py-2 py-lg-4 position-relative position-lg-absolute left-0 left-lg-n3 px-lg-4">')
# Missing colon in file 'darkmode.mplstyle', line 576 ('          <div class="border-bottom pb-3 mb-3">')
# Missing colon in file 'darkmode.mplstyle', line 577 ('            <ul class="list-style-none f5" >')
# Missing colon in file 'darkmode.mplstyle', line 578 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 579 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Open Source&quot;,&quot;action&quot;:&quot;click to go to GitHub Sponsors&quot;,&quot;label&quot;:&quot;ref_cta:GitHub Sponsors;&quot;}" href="/sponsors">')
# Missing colon in file 'darkmode.mplstyle', line 581 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 582 ('        <div class="color-fg-default h4">GitHub Sponsors</div>')
# Missing colon in file 'darkmode.mplstyle', line 583 ('        Fund open source developers')
# Missing colon in file 'darkmode.mplstyle', line 584 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 587 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 589 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 590 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 591 ('          <div class="border-bottom pb-3 mb-3">')
# Missing colon in file 'darkmode.mplstyle', line 592 ('            <ul class="list-style-none f5" >')
# Missing colon in file 'darkmode.mplstyle', line 593 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 594 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary d-flex flex-items-center" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Open Source&quot;,&quot;action&quot;:&quot;click to go to The ReadME Project&quot;,&quot;label&quot;:&quot;ref_cta:The ReadME Project;&quot;}" href="/readme">')
# Missing colon in file 'darkmode.mplstyle', line 596 ('      <div>')
# Missing colon in file 'darkmode.mplstyle', line 597 ('        <div class="color-fg-default h4">The ReadME Project</div>')
# Missing colon in file 'darkmode.mplstyle', line 598 ('        GitHub community articles')
# Missing colon in file 'darkmode.mplstyle', line 599 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 602 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 604 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 605 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 606 ('          <div class="">')
# Missing colon in file 'darkmode.mplstyle', line 607 ('              <span class="d-block h4 color-fg-default my-1" id="open-source-repositories-heading">Repositories</span>')
# Missing colon in file 'darkmode.mplstyle', line 608 ('            <ul class="list-style-none f5" aria-labelledby="open-source-repositories-heading">')
# Missing colon in file 'darkmode.mplstyle', line 609 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 610 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Open Source&quot;,&quot;action&quot;:&quot;click to go to Topics&quot;,&quot;label&quot;:&quot;ref_cta:Topics;&quot;}" href="/topics">')
# Missing colon in file 'darkmode.mplstyle', line 611 ('      Topics')
# Missing colon in file 'darkmode.mplstyle', line 614 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 616 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 617 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Open Source&quot;,&quot;action&quot;:&quot;click to go to Trending&quot;,&quot;label&quot;:&quot;ref_cta:Trending;&quot;}" href="/trending">')
# Missing colon in file 'darkmode.mplstyle', line 618 ('      Trending')
# Missing colon in file 'darkmode.mplstyle', line 621 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 623 ('                <li>')
# Duplicate key in file 'darkmode.mplstyle', line 624 ('  <a class="HeaderMenu-dropdown-link lh-condensed d-block no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header dropdown (logged out), Open Source&quot;,&quot;action&quot;:&quot;click to go to Collections&quot;,&quot;label&quot;:&quot;ref_cta:Collections;&quot;}" href="/collections">')
# Missing colon in file 'darkmode.mplstyle', line 625 ('      Collections')
# Missing colon in file 'darkmode.mplstyle', line 628 ('</a></li>')
# Missing colon in file 'darkmode.mplstyle', line 630 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 631 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 632 ('      </div>')
# Missing colon in file 'darkmode.mplstyle', line 633 ('</li>')
# Missing colon in file 'darkmode.mplstyle', line 636 ('                <li class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item">')
# Missing colon in file 'darkmode.mplstyle', line 638 ('</li>')
# Missing colon in file 'darkmode.mplstyle', line 640 ('            </ul>')
# Missing colon in file 'darkmode.mplstyle', line 641 ('          </nav>')
# Missing colon in file 'darkmode.mplstyle', line 643 ('        <div class="d-lg-flex flex-items-center mb-3 mb-lg-0 text-center text-lg-left ml-3" style="">')
# Missing colon in file 'darkmode.mplstyle', line 648 ('  <div')
# Missing colon in file 'darkmode.mplstyle', line 649 ('    class="search-input-container search-with-dialog position-relative d-flex flex-row flex-items-center mr-4 rounded"')
# Missing colon in file 'darkmode.mplstyle', line 651 ('  >')
# Missing colon in file 'darkmode.mplstyle', line 652 ('      <button')
# Missing colon in file 'darkmode.mplstyle', line 653 ('        type="button"')
# Missing colon in file 'darkmode.mplstyle', line 654 ('        class="header-search-button placeholder  input-button form-control d-flex flex-1 flex-self-stretch flex-items-center no-wrap width-full py-0 pl-2 pr-0 text-left border-0 box-shadow-none"')
# Missing colon in file 'darkmode.mplstyle', line 655 ('        data-target="qbsearch-input.inputButton"')
# Missing colon in file 'darkmode.mplstyle', line 656 ('        placeholder="Search or jump to..."')
# Missing colon in file 'darkmode.mplstyle', line 657 ('        data-hotkey=s,/')
# Missing colon in file 'darkmode.mplstyle', line 658 ('        autocapitalize="off"')
# Duplicate key in file 'darkmode.mplstyle', line 659 ('        data-action="click:qbsearch-input#handleExpand"')
# Missing colon in file 'darkmode.mplstyle', line 660 ('      >')
# Missing colon in file 'darkmode.mplstyle', line 661 ('        <div class="mr-2 color-fg-muted">')
# Missing colon in file 'darkmode.mplstyle', line 662 ('          <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-search">')
# Missing colon in file 'darkmode.mplstyle', line 663 ('    <path d="M10.68 11.74a6 6 0 0 1-7.922-8.982 6 6 0 0 1 8.982 7.922l3.04 3.04a.749.749 0 0 1-.326 1.275.749.749 0 0 1-.734-.215ZM11.5 7a4.499 4.499 0 1 0-8.997 0A4.499 4.499 0 0 0 11.5 7Z"></path>')
# Missing colon in file 'darkmode.mplstyle', line 664 ('</svg>')
# Missing colon in file 'darkmode.mplstyle', line 665 ('        </div>')
# Missing colon in file 'darkmode.mplstyle', line 666 ('        <span class="flex-1" data-target="qbsearch-input.inputButtonText">Search or jump to...</span>')
# Missing colon in file 'darkmode.mplstyle', line 667 ('          <div class="d-flex" data-target="qbsearch-input.hotkeyIndicator">')
# Missing colon in file 'darkmode.mplstyle', line 670 ('          </div>')
# Missing colon in file 'darkmode.mplstyle', line 671 ('      </button>')
# Missing colon in file 'darkmode.mplstyle', line 673 ('    <input type="hidden" name="type" class="js-site-search-type-field">')
# Missing colon in file 'darkmode.mplstyle', line 676 ('<div class="Overlay--hidden " data-modal-dialog-overlay>')
# Missing colon in file 'darkmode.mplstyle', line 678 ('      <h1 id="search-suggestions-dialog-header" class="sr-only">Search code, repositories, users, issues, pull requests...</h1>')
# Missing colon in file 'darkmode.mplstyle', line 679 ('    <div class="Overlay-body Overlay-body--paddingNone">')
# Missing colon in file 'darkmode.mplstyle', line 681 ('          <div data-view-component="true">        <div class="search-suggestions position-fixed width-full color-shadow-large border color-fg-default color-bg-default overflow-hidden d-flex flex-column query-builder-container"')
# Missing colon in file 'darkmode.mplstyle', line 683 ('          data-target="qbsearch-input.queryBuilderContainer"')
# Missing colon in file 'darkmode.mplstyle', line 684 ('          hidden')
# Missing colon in file 'darkmode.mplstyle', line 685 ('        >')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 15
#      13 with open('darkmode.mplstyle', 'wb') as f:
#      14     f.write(r.content)
# ---> 15 plt.style.use('darkmode.mplstyle')
#      17 def pulse(t, fc, tau):
#      18     """Transmit pulse function. Returns a Gaussian pulse modulated by a sinusoid.
#      19
#      20     Parameters
#    (...)
#      32         The transmit pulse.
#      33     """
#
# File c:\Users\vince\miniconda3\envs\jax\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     135 if isinstance(style, (str, Path)):
#     136     try:
# --> 137         style = _rc_params_in_file(style)
#     138     except OSError as err:
#     139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#
# File c:\Users\vince\miniconda3\envs\jax\Lib\site-packages\matplotlib\__init__.py:870, in _rc_params_in_file(fname, transform, fail_on_error)
#     868 for line_no, line in enumerate(fd, 1):
#     869     line = transform(line)
# --> 870     strippedline = cbook._strip_comment(line)
#     871     if not strippedline:
#     872         continue
#
# File c:\Users\vince\miniconda3\envs\jax\Lib\site-packages\matplotlib\cbook.py:419, in _strip_comment(s)
#     417 closing_quote_pos = s.find('"', quote_pos + 1)
#     418 if closing_quote_pos < 0:
# --> 419     raise ValueError(
#     420         f"Missing closing quote in: {s!r}. If you need a double-"
#     421         'quote inside a string, use escaping: e.g. "the \" char"')
#     422 pos = closing_quote_pos + 1
#
# ValueError: Missing closing quote in: '          <!-- \'"` --><!-- </textarea></xmp> --></option></form><form id="query-builder-test-form" action="" accept-charset="UTF-8" method="get">\n'. If you need a double-quote inside a string, use escaping: e.g. "the " char"

# %%
# Define the parameters
fc = 6e6
fs = 7 * fc
N = 512

# Generate the signal
t = np.linspace(0, N / fs, N)
x = pulse(t, fc, N / fs / 4) + np.random.randn(N) * 0.05

# Apply the Hilbert transform and obtain the analytic signal (cutting of the negative
# frequencies).
# NOTE: The hilbert function returns not the Hilbert transform but the analytic signal.
y = hilbert(x)
# Shift the signal to baseband
y = y * np.exp(-1j * t * 2 * np.pi * fc)

# Low-pass filter
filter_order = 8
normalized_cutoff = 0.2
b, a = butter(filter_order, normalized_cutoff, "low")

# Filter using a forward backward filter to prevent phase shift
y_lp = filtfilt(b, a, y)


# ======================================================================================
# Create a figure with plots of all steps in the demodulation process
# ======================================================================================

# Plot the results
fig, axes = plt.subplots(6, 1, figsize=(6, 10))

line_color = "#AA0000"
line_width = 0.5

axes[0].plot(t, x, color="#00AAAA", linewidth=line_width)
axes[0].set_title("Original signal x(t)")
axes[0].set_xlabel("time [us]")
axes[0].set_ylabel("amplitude")

fft_axis = fftshift(np.fft.fftfreq(N, 1 / fs))

axes[1].plot(fft_axis, fft_sh(x), color=line_color, linewidth=line_width)
axes[1].set_title("FFT of the signal x(t)")
axes[1].set_xlabel("frequency [Hz]")
axes[1].set_xticks(np.linspace(-fs / 2, fs / 2, 5))
axes[1].set_xticklabels(["$-1/2f_s$", "$-f_s/4$", "0", "$f_s/4$", "$f_s/2$"])

axes[2].plot(fft_axis, fft_sh(hilbert(x)), color=line_color, linewidth=line_width)
axes[2].set_title("FFT of the analytic signal of x(t)")
axes[2].set_xlabel("frequency [Hz]")
axes[2].set_xticks(np.linspace(-fs / 2, fs / 2, 5))
axes[2].set_xticklabels(["$-1/2f_s$", "$-f_s/4$", "0", "$f_s/4$", "$f_s/2$"])

axes[3].plot(fft_axis, fft_sh(y), color=line_color, linewidth=line_width)
axes[3].set_title("FFT of the analytic signal after shifting to baseband")
axes[3].set_xlabel("frequency [Hz]")
axes[3].set_xticks(np.linspace(-fs / 2, fs / 2, 5))
axes[3].set_xticklabels(["$-1/2f_s$", "$-f_s/4$", "0", "$f_s/4$", "$f_s/2$"])

axes[4].plot(fft_axis, fft_sh(y_lp), color=line_color, linewidth=line_width)
axes[4].set_title("FFT after then performing low-pass filtering")
axes[4].set_xlabel("frequency [Hz]")
axes[4].set_xticks(np.linspace(-fs / 2, fs / 2, 5))
axes[4].set_xticklabels(["$-1/2f_s$", "$-f_s/4$", "0", "$f_s/4$", "$f_s/2$"])

axes[5].plot(t, x, color="#00AAAA", linewidth=line_width, label="original signal")
axes[5].plot(
    t, np.abs(y_lp), color=line_color, linewidth=line_width, label="demodulated signal"
)
axes[5].set_title("Same plot but in time domain")

# ======================================================================================
# Make the plot black and the axis labels white
# ======================================================================================
for ax in axes:
    ax.set_facecolor("black")
    ax.tick_params(axis="x", colors="white")
    ax.tick_params(axis="y", colors="white")
    # ax.set_xlabel("frequency [Hz]")
    ax.set_ylabel("amplitude")
    # Make the labels and ticks white
    ax.xaxis.label.set_color("gray")
    ax.yaxis.label.set_color("gray")

    ax.spines["bottom"].set_color("white")
    ax.spines["left"].set_color("white")

    # Make the titles white
    ax.title.set_color("white")


# Make the figure black
fig.patch.set_facecolor("black")

plt.tight_layout()

output_dir = Path("../content/assets")
output_dir.mkdir(exist_ok=True, parents=True)

plt.savefig(output_dir/"demodulation.png", dpi=300)
